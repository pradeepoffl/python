# %%
## OOPS concepts

1.class 
2.object
3.inheritance
4.abstraction
5.encapsulation
6.polymorphism

#class has two properties 1.data properties
#                        2.Functionality 

# atm machine 
# data : 1. balance
#        2. pin 

#Functionality :

#  1. create pin
#  2. change pin
#  3. check balance
#  4. withdraw

# %% [markdown]
# fire fighter robot
#
# data:
# 1.head
# 2.legs
# 3.hands
# 4.no sensors
# 5.
#
# functionality:
#
# 1.movement
# 2.listen
# 3.speak

# %% [markdown]
# ## For refernce see class diagram you have draw

# %%
class Atm:
    #constructor (special function)- superpower
    
    def __init__(self):
        self.pin=""
        self.balance=0
        self.user_input=""
        self.menu()
    
    def menu(self):
        user_input =input("""Hi how can i help you?
            1. press 1 to create pin
            2. press 2 to change pin
            3. press 3 to check balance
            4. press 4 to withdraw
            5. Press 5 to exit"""
        )
        if user_input == '1':
        #creat pin 
            self.create_pin()

        elif user_input == "2":
            #change pin
            self.change_pin()
    
        elif user_input == "3":
        #check balance
            self.check_balance()

        elif user_input =="4":
        # withdraw
            self.withdraw()
        else:
            exit()
    
    def create_pin(self):
        user_pin=int(input("create a pin: "))
        self.pin=user_pin

        user_balance =int(input("enter balance:"))
        self.balance=user_balance

        print("pin created successfully")
        self.menu()

    
    def change_pin(self):
        old_pin=input("enter old pin:")
        if old_pin == self.pin:
            new_pin=input("Enter new pin:")
            self.pin = new_pin
            print("pin changed")
        else:
            print("wrong pin")


    def check_balance(self):
        pass
    def withdraw(self):
        pass

# %%
obj=Atm()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 obj=Atm()
#
# Cell In[22], line 8, in Atm.__init__(self)
#       6 self.balance=0
#       7 self.user_input=""
# ----> 8 self.menu()
#
# Cell In[22], line 20, in Atm.menu(self)
#      11 user_input =input("""Hi how can i help you?
#      12     1. press 1 to create pin
#      13     2. press 2 to change pin
#    (...)
#      16     5. Press 5 to exit"""
#      17 )
#      18 if user_input == '1':
#      19 #creat pin
# ---> 20     self.creat_pin()
#      22 elif user_input == "2":
#      23     #change pin
#      24     self.change_pin()
#
# AttributeError: 'Atm' object has no attribute 'creat_pin'

# %%
# Out:
# 8
